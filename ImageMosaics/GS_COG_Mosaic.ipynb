# %% [markdown]
# # GeoServer ImageMosaic Configuration
# COGs will be used to create an ImageMosaic in GeoServer

# %% [markdown]
# ## Step 1: Configuration Files Setup

# %% [markdown]
# ### Choose parameters
# Set the parameters for the layer and database.

# %%
layer_name = 'mosaic_test' # this *should* be the same as the db_name as it may cause issues if not...
workspace = 'test2' # If there is no existing workspace in this name, it will be created

db_name = layer_name # Note: For a PostGIS datastore, it is not needed that the database is already present in the PostGIS instance; it will be created automatically by the ImageMosaic reader.
pg_user = 'postgres' 
pg_password = 'stac' 
pg_port = '5432' # Default port 

# Base GeoServer URL and credentials
base_url = "http://localhost:8080/geoserver" 
store_name = layer_name
user = "admin" 
password = "geoserver" 

# EPSG of the granules provided
EPSG = '3005'

# Fill this list with http links for the granules
granules_list = [
    "https://nrs.objectstore.gov.bc.ca/cloudgistest/test/cog_out/granules/wvge_c10683_c1r1_2017_bcalb_500mm_fcir_enh.tif",
    "https://nrs.objectstore.gov.bc.ca/cloudgistest/test/cog_out/granules/wvge_c10683_c1r2_2017_bcalb_500mm_fcir_enh.tif",
]

# %% [markdown]
# ### Initialize .properties files
# Create the necessary .properties files for configuring the ImageMosaic.

# %%
''' 
The indexer.properties file can be useful to extract timestamps, integers, etc from a filename and sort them that way. 
This might be useful? But for now and our basic mosaic, we can keep this file simple. 
'''

# indexer.properties
indexer_properties = f"""Cog=true
PropertyCollectors=
TimeAttribute=time
Schema=*the_geom:Polygon,location:String,time:java.util.Date
CanBeEmpty=true
Name={layer_name}
MosaicCRS=EPSG:{EPSG} 
"""
                #? EPSG is BC Albers - change if needed

# datastore.properties
datastore_properties = f'''user={pg_user}
port={pg_port}
passwd={pg_password}
url=jdbc:postgresql:{db_name}
host=localhost
database={db_name}
driver=org.postgresql.Driver
schema=public
SPI=org.geotools.data.postgis.PostgisNGDataStoreFactory
fetch\\ size=1000
max\\ connections=20
min\\ connections=5
validate\\ connections=true
Loose\\ bbox=true
Expose\\ primary\\ key=false
Max\\ open\\ prepared\\ statements=50
preparedStatements=false
Estimated\\ extends=false
Connection\\ timeout=20
'''


import zipfile
import os

# %% [markdown]
# ### Create a zip archive with the configuration files
# Bundle the .properties files into a single ZIP archive for uploading to GeoServer.

# %%
zip_name = f'{layer_name}.zip'

with zipfile.ZipFile(zip_name, 'w') as zipf:
    with zipf.open('indexer.properties', 'w') as f:
        f.write(indexer_properties.encode())
    with zipf.open('datastore.properties', 'w') as f:
        f.write(datastore_properties.encode())

# %%
import requests
from requests.auth import HTTPBasicAuth

# GeoServer credentials and URL
workspaces_url = base_url + '/rest/workspaces/'
username = "admin"
password = "geoserver"

# Workspace name

# Function to check if the workspace exists
def workspace_exists(workspace_name):
    response = requests.get(
        f"{workspaces_url}/{workspace_name}",
        auth=HTTPBasicAuth(username, password)
    )
    return response.status_code == 200

# Function to create a workspace
def create_workspace(workspace_name):
    payload = f"""
    <workspace>
      <name>{workspace_name}</name>
    </workspace>
    """
    headers = {
        "Content-Type": "application/xml"
    }
    response = requests.post(
        workspaces_url,
        data=payload,
        headers=headers,
        auth=HTTPBasicAuth(username, password)
    )
    if response.status_code == 201:
        print("Workspace created successfully!")
    else:
        print(f"Failed to create workspace: {response.status_code}, {response.text}")

# Check if the workspace exists and create it if not
if not workspace_exists(workspace):
    create_workspace(workspace)
else:
    print(f"Workspace '{workspace}' already exists.")
# Out:
# Workspace 'test2' already exists.

# %% [markdown]
# ## Step 2: REST API Calls to GeoServer
# Use the GeoServer REST API to configure the ImageMosaic. This involves creating an empty ImageMosaic, providing a prototype dataset, initializing the store, configuring the coverage, and adding more granules.

# %%
# 1. Create an empty ImageMosaic
url = f"{base_url}/rest/workspaces/{workspace}/coveragestores/{store_name}/file.imagemosaic?configure=none"
headers = {"Content-type": "application/zip"}

with open(zip_name, 'rb') as file:
    response = requests.put(url, auth=(user, password), headers=headers, data=file)
print(f"Create empty ImageMosaic response: {response.status_code}")
# Out:
# Create empty ImageMosaic response: 201

# %%
# 2. Provide a prototype dataset
url = f"{base_url}/rest/workspaces/{workspace}/coveragestores/{store_name}/remote.imagemosaic"
headers = {"Content-type": "text/plain"}
if granules_list[0]: data = granules_list[0] 
response = requests.post(url, auth=(user, password), headers=headers, data=data)
print(f"Provide prototype dataset response: {response.status_code}")
# Out:
# Provide prototype dataset response: 202

# %%
# 3. Initialize the store (Listing available coverages)
url = f"{base_url}/rest/workspaces/{workspace}/coveragestores/{store_name}/coverages.xml?list=all"
response = requests.get(url, auth=(user, password))
print(f"Initialize the store response: {response.status_code}")
print(response.text)
# Out:
# Initialize the store response: 200
# <list>
#   <coverageName>mosaic_test</coverageName>
# </list>

# %% [markdown]
# The output should be:
# ```
# <list>
#   <coverageName>(your layer name)</coverageName>
# </list>
# ```

# %%
# 4. Configure the coverage
coverage_xml = f"""
<coverage>
  <name>{layer_name}</name>
  <nativeName>{layer_name}</nativeName>
  <enabled>true</enabled>
  <metadata>
  </metadata>
</coverage>
"""
url = f"{base_url}/rest/workspaces/{workspace}/coveragestores/{store_name}/coverages"
headers = {"Content-type": "text/xml"}
response = requests.post(url, auth=(user, password), headers=headers, data=coverage_xml)
print(f"Configure the coverage response: {response.status_code}")
# Out:
# Configure the coverage response: 201

# %%
# 5. Add more granules
number_granules = len(granules_list)
if number_granules > 1:
    for granule_number in range(1, number_granules): # Add other granules
        url = f"{base_url}/rest/workspaces/{workspace}/coveragestores/{store_name}/remote.imagemosaic"
        data = granules_list[granule_number]
        response = requests.post(url, auth=(user, password), headers=headers, data=data)
        print(f"Adding more granules response: {response.status_code}")
else:
    print('No more granules to add')
# Out:
# 2
# Adding more granules response: 202

# %%
# Verify that the ImageMosaic layer exists and get details
url = f"{base_url}/rest/layers/{store_name}.xml"
response = requests.get(url, auth=(user, password))

if response.status_code == 200:
    print("ImageMosaic layer exists.")
    # Print the details of the layer
    print("Layer details:")
    print(response.text)
else:
    print(f"Failed to find the ImageMosaic layer. Status code: {response.status_code}")

# Get details about the granules in the coverage
coverage_url = f"{base_url}/rest/workspaces/{workspace}/coveragestores/{store_name}/coverages.xml"
coverage_response = requests.get(coverage_url, auth=(user, password))

if coverage_response.status_code == 200:
    print("Coverage details:")
    print(coverage_response.text)
else:
    print(f"Failed to get coverage details. Status code: {coverage_response.status_code}")
# Out:
# ImageMosaic layer exists.
# Layer details:
# <layer>
#   <name>mosaic_test</name>
#   <type>RASTER</type>
#   <defaultStyle>
#     <name>raster</name>
#     <atom:link xmlns:atom="http://www.w3.org/2005/Atom" rel="alternate" href="http://localhost:8080/geoserver/rest/styles/raster.xml" type="application/xml"/>
#   </defaultStyle>
#   <resource class="coverage">
#     <name>test2:mosaic_test</name>
#     <atom:link xmlns:atom="http://www.w3.org/2005/Atom" rel="alternate" href="http://localhost:8080/geoserver/rest/workspaces/test2/coveragestores/mosaic_test/coverages/mosaic_test.xml" type="application/xml"/>
#   </resource>
#   <attribution>
#     <logoWidth>0</logoWidth>
#     <logoHeight>0</logoHeight>
#   </attribution>
#   <dateCreated>2024-08-27 16:13:59.570 UTC</dateCreated>
# </layer>
# Coverage details:
# <coverages>
#   <coverage>
#     <name>mosaic_test</name>
#     <atom:link xmlns:atom="http://www.w3.org/2005/Atom" rel="alternate" href="http://localhost:8080/geoserver/rest/workspaces/test2/coveragestores/mosaic_test/coverages/mosaic_test.xml" type="application/atom+xml"/>
#   </coverage>
# </coverages>
